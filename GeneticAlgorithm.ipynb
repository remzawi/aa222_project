# %% [markdown]
# Notebook for testing the particle swarm optimization

# %% [markdown]
# Download cifar dataset if not present

# %%
from LoadCIFAR import loadCIFAR
loadCIFAR()
# Out:
# Already loaded.

# %% [markdown]
# Util functions to save and load objects

# %%
import pickle

def save_obj(obj, name ):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %% [markdown]
# Import files

# %%
import numpy as np
import tensorflow as tf
from optimizers import *

# %% [markdown]
# Test GA function

# %%
params={'learning_rate':(1e-5,1e-1,2),
        'batch_size':(32,256,1),
        'nepochs':(8,8,1),
        'conv_size1':(32,128,1),
        'conv_size2':(32,128,1),
        'conv_size3':(32,128,1),
        'fc_size':(50,200,1),
        'dropout_param':(0,0.6,0),
        'l2_reg':(1e-10,1,2)}
model_params,y_best,x_history,y_history=GA(6,4,3,params=params,num_training=9000,num_val=1000,keras_verbose=2)
# Out:
# WARNING:tensorflow:Large dropout rate: 0.592454 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/8
# WARNING:tensorflow:Large dropout rate: 0.592454 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.592454 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# 9000/9000 - 5s - loss: 2.1477 - sparse_categorical_accuracy: 0.2730 - val_loss: 2.1759 - val_sparse_categorical_accuracy: 0.1760
# Epoch 2/8
# 9000/9000 - 2s - loss: 1.6916 - sparse_categorical_accuracy: 0.3829 - val_loss: 2.2026 - val_sparse_categorical_accuracy: 0.1800
# Epoch 3/8
# 9000/9000 - 2s - loss: 1.5193 - sparse_categorical_accuracy: 0.4471 - val_loss: 2.0161 - val_sparse_categorical_accuracy: 0.2840
# Epoch 4/8
# ...

# %%
print(model_params)
# Out:
# {'nepochs': 8, 'learning_rate': 0.00017481430931192823, 'batch_size': 125.0, 'conv_size1': 74.0, 'conv_size2': 94.0, 'conv_size3': 92.0, 'fc_size': 192.0, 'dropout_param': 0.5924535287766974, 'l2_reg': 4.6234353012145104e-10}

# %% [markdown]
# Run for 200 evaluations

# %%
params={'learning_rate':(1e-5,1e-1,2),
        'batch_size':(32,256,1),
        'nepochs':(8,8,1),
        'conv_size1':(32,128,1),
        'conv_size2':(32,128,1),
        'conv_size3':(32,128,1),
        'fc_size':(50,200,1),
        'dropout_param':(0,0.6,0),
        'l2_reg':(1e-10,1,2)}
best_params,y_best,x_history,y_history=GA(10,19,5,params=params,num_training=49000,num_val=1000,keras_verbose=0)
save_obj(best_params,'GAOptParam200')
save_obj(y_best,'GAScore200')
save_obj(y_history,'GAHistory200')
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]
# Starting optimization loop
# 100%|██████████| 19/19 [5:20:54<00:00, 1013.38s/it]
# Final evaluation

# %%
print(best_params)
# Out:
# {'nepochs': 8, 'learning_rate': 0.001172468301071695, 'batch_size': 32.0, 'conv_size1': 107.0, 'conv_size2': 86.0, 'conv_size3': 109.0, 'fc_size': 160.0, 'dropout_param': 0.2617519889727094, 'l2_reg': 8.292267029306733e-09}

# %%
print(y_history)
# Out:
# [0.7440000176429749, 0.8029999732971191, 0.8069999814033508]

# %%
print(x_history)
# Out:
# [array([2.58178919e-04, 2.17000000e+02, 1.14000000e+02, 4.60000000e+01,
#        1.25000000e+02, 1.86000000e+02, 3.13100384e-01, 1.22164890e-05]), array([1.05828356e-03, 3.20000000e+01, 1.10000000e+02, 5.60000000e+01,
#        1.00000000e+02, 1.74000000e+02, 3.17711494e-01, 1.00000000e-10]), array([1.17246830e-03, 3.20000000e+01, 1.07000000e+02, 8.60000000e+01,
#        1.09000000e+02, 1.60000000e+02, 2.61751989e-01, 8.29226703e-09])]
