# %% [markdown]
# Notebook for testing the particle swarm optimization

# %% [markdown]
# Download cifar dataset if not present

# %%
from LoadCIFAR import loadCIFAR
loadCIFAR()
# Out:
# Already loaded.

# %% [markdown]
# Util functions to save and load objects

# %%
import pickle

def save_obj(obj, name ):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %% [markdown]
# Import files

# %%
import numpy as np
import tensorflow as tf
from optimizers import *

# %% [markdown]
# Test GPfunction

# %%
params={'learning_rate':(1e-5,1e-1,2),
        'batch_size':(32,256,1),
        'nepochs':(8,8,1),
        'conv_size1':(32,128,1),
        'conv_size2':(32,128,1),
        'conv_size3':(32,128,1),
        'fc_size':(50,200,1),
        'dropout_param':(0,0.5,0),
        'l2_reg':(1e-10,1,2)}
model_params,y_best,x_history,y_history=GP(6,4,3,params=params,num_training=9000,num_val=1000,keras_verbose=2)
# Out:
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/8
# 9000/9000 - 6s - loss: 2.3241 - sparse_categorical_accuracy: 0.2072 - val_loss: 2.2215 - val_sparse_categorical_accuracy: 0.2120
# Epoch 2/8
# 9000/9000 - 2s - loss: 1.8868 - sparse_categorical_accuracy: 0.3268 - val_loss: 2.1848 - val_sparse_categorical_accuracy: 0.1600
# Epoch 3/8
# 9000/9000 - 2s - loss: 1.7319 - sparse_categorical_accuracy: 0.3758 - val_loss: 2.2148 - val_sparse_categorical_accuracy: 0.1840
# Epoch 4/8
# 9000/9000 - 2s - loss: 1.6187 - sparse_categorical_accuracy: 0.4179 - val_loss: 2.1230 - val_sparse_categorical_accuracy: 0.2220
# Epoch 5/8
# 9000/9000 - 2s - loss: 1.5259 - sparse_categorical_accuracy: 0.4543 - val_loss: 2.0342 - val_sparse_categorical_accuracy: 0.2520
# Epoch 6/8
# 9000/9000 - 2s - loss: 1.4678 - sparse_categorical_accuracy: 0.4732 - val_loss: 1.8256 - val_sparse_categorical_accuracy: 0.3150
# Epoch 7/8
# ...

# %%
print(model_params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8ce1bbadcda1> in <module>
# ----> 1 print(model_params)
#
# NameError: name 'model_params' is not defined

# %% [markdown]
# Run for 100 evaluations

# %%
params={'learning_rate':(1e-5,1e-1,2),
        'batch_size':(32,256,1),
        'nepochs':(8,8,1),
        'conv_size1':(32,128,1),
        'conv_size2':(32,128,1),
        'conv_size3':(32,128,1),
        'fc_size':(50,200,1),
        'dropout_param':(0,0.5,0),
        'l2_reg':(1e-10,1,2)}
best_params,y_best,x_history,y_history=GP(12,15,7,params=params,num_training=49000,num_val=1000,keras_verbose=0)
save_obj(best_params,'GPOptParam2')
save_obj(y_best,'GPScore2')
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# Starting optimization loop
# 100%|██████████| 15/15 [3:08:55<00:00, 755.68s/it]
# Final evaluation

# %%
print(best_params)
# Out:
# {'nepochs': 8, 'learning_rate': 0.0006556455048899933, 'batch_size': 133.0, 'conv_size1': 32.0, 'conv_size2': 100.0, 'conv_size3': 53.0, 'fc_size': 64.0, 'dropout_param': 0.1446082838091047, 'l2_reg': 0.0002915301664244039}

# %%
print(y_history)
# Out:
# [0.7379999756813049, 0.7749999761581421, 0.7639999985694885, 0.7649999856948853, 0.7649999856948853, 0.7620000243186951, 0.7689999938011169, 0.7639999985694885, 0.7720000147819519, 0.7609999775886536, 0.7630000114440918, 0.781000018119812, 0.7540000081062317, 0.7570000290870667, 0.7689999938011169, 0.7580000162124634]

# %%
print(x_history)
# Out:
# [array([6.32005698e-04, 1.06000000e+02, 3.60000000e+01, 4.60000000e+01,
#        7.70000000e+01, 1.21000000e+02, 1.22507863e-01, 4.72134773e-10]), array([7.33456864e-04, 1.12000000e+02, 4.40000000e+01, 7.80000000e+01,
#        7.70000000e+01, 7.40000000e+01, 2.42903092e-01, 5.27425219e-08]), array([7.13680009e-04, 9.70000000e+01, 4.30000000e+01, 8.30000000e+01,
#        7.50000000e+01, 7.60000000e+01, 2.34687280e-01, 5.23100993e-08]), array([7.22133042e-04, 1.14000000e+02, 4.40000000e+01, 8.70000000e+01,
#        7.90000000e+01, 1.16000000e+02, 1.62113509e-01, 9.36128845e-05]), array([6.74437287e-04, 9.70000000e+01, 3.20000000e+01, 8.70000000e+01,
#        6.80000000e+01, 9.50000000e+01, 1.77400179e-01, 4.45586913e-04]), array([5.43691741e-04, 8.80000000e+01, 3.40000000e+01, 1.03000000e+02,
#        6.60000000e+01, 8.60000000e+01, 2.28874468e-01, 1.00079282e-04]), array([6.35412128e-04, 1.14000000e+02, 5.80000000e+01, 1.02000000e+02,
# ...
